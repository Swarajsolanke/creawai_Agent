# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# %pip install crewai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os 
print(os.listdir())
# Out:
# ['.env', '.git', '.gitignore', '.python-version', '.venv', 'email_agent.ipynb', 'main.py', 'pyproject.toml', 'README.md', 'uv.lock']

# %%
from crewai import LLM

llm=LLM(
    model="gemini/gemini-2.0-flash",
    temperature=0.1
)
llm.call("who is the gold of cricket ")
# Out:
# 'There\'s no single, universally agreed-upon "gold of cricket." However, the term is often used metaphorically to describe the most valuable, prestigious, or sought-after achievements in the sport. Here are a few interpretations:\n\n*   **The Cricket World Cup:** Winning the Cricket World Cup is arguably the pinnacle of achievement in international cricket. It\'s the most prestigious tournament and represents the ultimate team success.\n\n*   **Individual Records and Milestones:** Some might consider achieving certain individual records, like scoring the most runs in Test cricket (currently held by Sachin Tendulkar) or taking the most wickets (currently held by Muttiah Muralitharan), as the "gold" for individual players.\n\n*   **Consistent Excellence Over Time:** Others might argue that sustained excellence and impact on the game over a long career, like that of Don Bradman, Sachin Tendulkar, or Shane Warne, represents the true "gold" of cricket.\n\n*   **The Ashes:** For England an
# ...

# %%
from crewai import Agent, Task, Crew

# %%
email_assistant=Agent(
    role="Email Assistant Agent", 
    goal="Improve email and makee them sound professional and clear, polite and concise",
    backstory="A highly exprienced communication expert skilled in professional email writing",
    verbose=True,
    llm=llm
)

original_email =  "hey team ,just wanted to tell u that the demo is the kind of ready, but there's still stuff left. maybe we can show what we have and say rest in WIP.let me know what u think, thank"

email_task =Task(
    description=f"take the following rough email and rewrite it into a professional and version Expand abbreviation '''' {original_email}''' ",
    agent=email_assistant,
    expected_output="A professionally written email with proper formatting and content that conveys the intended message clearly and politely."

)

crew = Crew(
    agents = [email_assistant],
    tasks = [email_task],
    verbose=True
)
result=crew.kickoff()
print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 48d6a8fe-aaa4-4e07-99e8-5122a48f7b48                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ...

# %%
print("AI agent Pipeline is calling")
# Out:
# AI agent Pipeline is calling
